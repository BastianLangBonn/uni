# %%
import getpass, socket, time

print (getpass.getuser() + " on " + socket.gethostname())
print (time.strftime("%d-%m-%Y %H:%M"))
# Out:
# bastian on bastian-ThinkPad-T420
# 12-04-2016 09:13

# %%
import pydotplus
import sklearn
from sklearn import tree
from sklearn.externals.six import StringIO
from IPython.display import Image 
import numpy as np

data = np.genfromtxt(fname='zoo.data', delimiter=',');
data = data[:,1:]
targets = data[:,-1]

# Split Data
split = sklearn.cross_validation.train_test_split(data)

training_data = split[0]
training_target = training_data[:,-1]
training_data = training_data[:,:-1]

test_data = split[1]
test_target = test_data[:,-1]
test_data = test_data[:,:-1]


clf = tree.DecisionTreeClassifier()
clf = clf.fit(training_data, training_target)

dot_data = StringIO()  
tree.export_graphviz(clf, out_file=dot_data,  
                     #feature_names=iris.feature_names,  
                     #class_names=iris.target_names,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
